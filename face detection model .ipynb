# %%
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default (1).xml')

# %%
img= cv2.imread('41964.jpg')

# %%
faces = face_cascade.detectMultiScale(img,1.1,4) #detect face

# %%
#draw rectangle around faces
for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
#export image
cv2.imwrite("face_detected.png",img)
print('photo sucessfully exported!')
# Out:
# photo sucessfully exported!

# %%
plt.imshow(img)
